# %% [markdown]
# # Load model from HF

# %%
from huggingface_hub import login
access_token = os.environ['HF_TOKEN']
login(access_token)

# %%
from mlx_lm import generate, load
model, tokenizer = load("Qwen/Qwen2.5-1.5B")
# Out:
# Fetching 7 files:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
prompt = "What is under-fitting and overfitting in machine learning?"

messages = [{"role": "user", "content": prompt}]
prompt = tokenizer.apply_chat_template(
    messages, tokenize=False, add_generation_prompt=True
)

response = generate(model, tokenizer, prompt=prompt, verbose=True, max_tokens = 100)
# Out:
# ==========
#  is the difference between under-fitting and overfitting in machine learning? under-fitting and overfitting are two common problems in machine learning. under-fitting occurs when a model is too simple to capture the underlying patterns in the data, resulting in poor performance on both training and test data. overfitting, on the other hand, occurs when a model is too complex and captures the noise in the training data, resulting in poor performance on the test data. under-fitting and over
# ==========
# Prompt: 32 tokens, 342.624 tokens-per-sec
# Generation: 100 tokens, 95.709 tokens-per-sec
# Peak memory: 3.110 GB

# %% [markdown]
# # Loading the dataset

# %%
import json

class Dataset:
    """
    Light-weight wrapper to hold lines from a jsonl file
    """

    def __init__(self, path: Path, key: str = "text"):
        if not path.exists():
            self._data = None
        else:
            with open(path, "r") as fid:
                self._data = [json.loads(l) for l in fid]
        self._key = key

    def __getitem__(self, idx: int):
        return self._data[idx][self._key]

    def __len__(self):
        return len(self._data)

def load():
    def load_and_check(path):
        try:
            return Dataset(Path(path))
        except Exception as e:
            print(f"Unable to build dataset {path} ({e})")
            raise

    train = load_and_check('../data/train.jsonl')
    test = load_and_check('../data/valid.jsonl')

    if len(train) == 0:
        raise ValueError("Training set not found or empty")
    if len(test) == 0:
        raise ValueError("Test set not found or empty")

    return train, test

# %%
train_set, dev_set = load()

# %%
from datasets import load_dataset
ds = load_dataset("win-wang/Machine_Learning_QA_Collection")
# Out:
# README.md:   0%|          | 0.00/1.62k [00:00<?, ?B/s]
# train.jsonl:   0%|          | 0.00/8.13M [00:00<?, ?B/s]
# valid.jsonl:   0%|          | 0.00/1.17M [00:00<?, ?B/s]
# test.jsonl:   0%|          | 0.00/2.34M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/8652 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/1235 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/2471 [00:00<?, ? examples/s]

# %%
import pandas as pd
train_set = pd.DataFrame(ds["train"])
dev_set = pd.DataFrame(ds["validation"])
test_set = pd.DataFrame(ds["test"])
train_set.head()
# Out:
#                                                 text
# 0  <start_of_turn>user\n    I am solving a system...
# 1  <start_of_turn>user\n    I get a gtk-WARNING w...
# 2  <start_of_turn>user\n    I don't really like w...
# 3  <start_of_turn>user\n    I am having trouble f...
# 4  <start_of_turn>user\n    How do Recurrent Neur...

# %%
# MLX requires the data to be placed in a container that allows random access. Here, we convert it into a Python built-in list
def preprocess(dataset):
    return dataset["text"].tolist()
    
train_set, dev_set, test_set = map(preprocess, (train_set, dev_set, test_set))

# %% [markdown]
# # Model fine-tuning

# %%
import matplotlib.pyplot as plt
import mlx.optimizers as optim
from mlx.utils import tree_flatten
from mlx_lm import load, generate
from mlx_lm.tuner.trainer import iterate_batches
from mlx_lm.tuner import train, TrainingArgs
from mlx_lm.tuner import linear_to_lora_layers
from pathlib import Path
import json

# %%
adapter_path = Path("adapters")
adapter_path.mkdir(parents=True, exist_ok=True)

# %%
lora_config = {
 "lora_layers": 8,
 "lora_parameters": {
    "rank": 8,
    "scale": 20.0,
    "dropout": 0.0,
}}

# %%
with open(adapter_path / "adapter_config.json", "w") as fid:
    json.dump(lora_config, fid, indent=4)

# %%
training_args = TrainingArgs(
    adapter_file=adapter_path / "adapters.safetensors",
    iters=200,
    steps_per_eval=50
)

# %%
model.freeze()
# Out:
# Model(
#   (model): Qwen2Model(
#     (embed_tokens): Embedding(151936, 1536)
#     (layers.0): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): Linear(input_dims=1536, output_dims=1536, bias=True)
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.1): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): Linear(input_dims=1536, output_dims=1536, bias=True)
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.2): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): Linear(input_dims=1536, output_dims=1536, bias=True)
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.3): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): Linear(input_dims=1536, output_dims=1536, bias=True)
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.4): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): Linear(input_dims=1536, output_dims=1536, bias=True)
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.5): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): Linear(input_dims=1536, output_dims=1536, bias=True)
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.6): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): Linear(input_dims=1536, output_dims=1536, bias=True)
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.7): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): Linear(input_dims=1536, output_dims=1536, bias=True)
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.8): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): Linear(input_dims=1536, output_dims=1536, bias=True)
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.9): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): Linear(input_dims=1536, output_dims=1536, bias=True)
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.10): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): Linear(input_dims=1536, output_dims=1536, bias=True)
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.11): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): Linear(input_dims=1536, output_dims=1536, bias=True)
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.12): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): Linear(input_dims=1536, output_dims=1536, bias=True)
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.13): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): Linear(input_dims=1536, output_dims=1536, bias=True)
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.14): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): Linear(input_dims=1536, output_dims=1536, bias=True)
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.15): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): Linear(input_dims=1536, output_dims=1536, bias=True)
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.16): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): Linear(input_dims=1536, output_dims=1536, bias=True)
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.17): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): Linear(input_dims=1536, output_dims=1536, bias=True)
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.18): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): Linear(input_dims=1536, output_dims=1536, bias=True)
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.19): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): Linear(input_dims=1536, output_dims=1536, bias=True)
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.20): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): Linear(input_dims=1536, output_dims=1536, bias=True)
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.21): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): Linear(input_dims=1536, output_dims=1536, bias=True)
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.22): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): Linear(input_dims=1536, output_dims=1536, bias=True)
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.23): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): Linear(input_dims=1536, output_dims=1536, bias=True)
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.24): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): Linear(input_dims=1536, output_dims=1536, bias=True)
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.25): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): Linear(input_dims=1536, output_dims=1536, bias=True)
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.26): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): Linear(input_dims=1536, output_dims=1536, bias=True)
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.27): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): Linear(input_dims=1536, output_dims=1536, bias=True)
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (norm): RMSNorm(1536, eps=1e-06)
#   )
# )

# %%
linear_to_lora_layers(model, lora_config["lora_layers"], lora_config["lora_parameters"])

# %%
num_train_params = (
    sum(v.size for _, v in tree_flatten(model.trainable_parameters()))
)
print(f"Number of trainable parameters: {num_train_params}")
# Out:
# Number of trainable parameters: 1089536

# %%
model.train()
# Out:
# Model(
#   (model): Qwen2Model(
#     (embed_tokens): Embedding(151936, 1536)
#     (layers.0): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=1536, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=256, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.1): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=1536, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=256, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.2): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=1536, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=256, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.3): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=1536, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=256, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.4): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=1536, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=256, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.5): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=1536, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=256, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.6): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=1536, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=256, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.7): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=1536, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=256, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.8): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=1536, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=256, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.9): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=1536, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=256, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.10): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=1536, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=256, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.11): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=1536, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=256, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.12): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=1536, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=256, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.13): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=1536, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=256, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.14): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=1536, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=256, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.15): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=1536, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=256, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.16): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=1536, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=256, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.17): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=1536, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=256, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.18): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=1536, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=256, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.19): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=1536, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=256, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.20): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=1536, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=256, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.21): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=1536, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=256, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.22): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=1536, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=256, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.23): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=1536, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=256, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.24): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=1536, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=256, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.25): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=1536, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=256, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.26): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=1536, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=256, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (layers.27): TransformerBlock(
#       (self_attn): Attention(
#         (q_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=1536, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (k_proj): Linear(input_dims=1536, output_dims=256, bias=True)
#         (v_proj): LoRALinear(
#           (linear): Linear(input_dims=1536, output_dims=256, bias=True)
#           (dropout): Dropout(p=0.0)
#         )
#         (o_proj): Linear(input_dims=1536, output_dims=1536, bias=False)
#         (rope): RoPE(128, traditional=False)
#       )
#       (mlp): MLP(
#         (gate_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#         (down_proj): Linear(input_dims=8960, output_dims=1536, bias=False)
#         (up_proj): Linear(input_dims=1536, output_dims=8960, bias=False)
#       )
#       (input_layernorm): RMSNorm(1536, eps=1e-06)
#       (post_attention_layernorm): RMSNorm(1536, eps=1e-06)
#     )
#     (norm): RMSNorm(1536, eps=1e-06)
#   )
# )

# %%
opt = optim.Adam(learning_rate=1e-5)

# %%
class Metrics:
    train_losses = []
    val_losses = []
    def on_train_loss_report(self, info):
        self.train_losses.append((info["iteration"], info["train_loss"]))
    def on_val_loss_report(self, info):
        self.val_losses.append((info["iteration"], info["val_loss"]))
        
metrics = Metrics()

# %%
train(
    model = model,
    tokenizer = tokenizer,
    args = training_args,
    optimizer = opt,
    train_dataset = train_set,
    val_dataset = dev_set,
    training_callback = metrics
)
# Out:
# Starting training..., iters: 200
# [WARNING] Some sequences are longer than 2048 tokens. The longest sentence 2606 will be truncated to 2048. Consider pre-splitting your data to save memory.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 train(
#       2     model = model,
#       3     tokenizer = tokenizer,
#       4     args = training_args,
#       5     optimizer = opt,
#       6     train_dataset = train_set,
#       7     val_dataset = dev_set,
#       8     training_callback = metrics
#       9 )
#
# File ~/Library/Caches/pypoetry/virtualenvs/core-lm-41KgHC7s-py3.12/lib/python3.12/site-packages/mlx_lm/tuner/trainer.py:222, in train(model, tokenizer, optimizer, train_dataset, val_dataset, args, loss, iterate_batches, training_callback)
#     220 # Main training loop
#     221 start = time.perf_counter()
# --> 222 for it, batch in zip(
#     223     range(1, args.iters + 1),
#     224     iterate_batches(
#     225         dataset=train_dataset,
#     226         tokenizer=tokenizer,
#     227         batch_size=args.batch_size,
#     228         max_seq_length=args.max_seq_length,
#     229         train=True,
#     230     ),
#     231 ):
#     232     # Report validation loss if needed, the first validation loss
#     233     # is always measured before any training.
#     234     if it == 1 or it % args.steps_per_eval == 0 or it == args.iters:
#     235         stop = time.perf_counter()
#
# File ~/Library/Caches/pypoetry/virtualenvs/core-lm-41KgHC7s-py3.12/lib/python3.12/site-packages/mlx_lm/tuner/trainer.py:121, in iterate_batches(dataset, tokenizer, batch_size, max_seq_length, train)
#     119 for j in range(batch_size // step):
#     120     truncated_length = min(lengths[j], max_seq_length)
# --> 121     batch_arr[j, :truncated_length] = batch[j][:truncated_length]
#     122     lengths[j] = (
#     123         truncated_length  # Update lengths to match truncated lengths
#     124     )
#     125 batch = mx.array(batch_arr)
#
# ValueError: invalid literal for int() with base 10: "<s>[INST] Can I use the block editor to create a custom search engine or indexing tool for my site, and what are the benefits?[/INST] Yes, you can leverage the block editor (also known as Gutenberg)

# %%
sample_batch = next(iter(iterate_batches(
    dataset=train_set,
    tokenizer=tokenizer,
    batch_size=1,
    max_seq_length=2000,
    train=True,
)))
print(sample_batch)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 sample_batch = next(iter(iterate_batches(
#       2     dataset=train_set,
#       3     tokenizer=tokenizer,
#       4     batch_size=1,
#       5     max_seq_length=2000,
#       6     train=True,
#       7 )))
#       8 print(sample_batch)
#
# File ~/Library/Caches/pypoetry/virtualenvs/core-lm-41KgHC7s-py3.12/lib/python3.12/site-packages/mlx_lm/tuner/trainer.py:121, in iterate_batches(dataset, tokenizer, batch_size, max_seq_length, train)
#     119 for j in range(batch_size // step):
#     120     truncated_length = min(lengths[j], max_seq_length)
# --> 121     batch_arr[j, :truncated_length] = batch[j][:truncated_length]
#     122     lengths[j] = (
#     123         truncated_length  # Update lengths to match truncated lengths
#     124     )
#     125 batch = mx.array(batch_arr)
#
# ValueError: invalid literal for int() with base 10: '<s>[INST] Where can I find a good WordPress hosting provider?[/INST] There are several reputable WordPress hosting providers you can consider:\n\n1. Bluehost: An official WordPress recommended hostin
